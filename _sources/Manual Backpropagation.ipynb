# %% [markdown]
# # **Manual Backpropagation**

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Firdatulayuni/Pendata/main/Manual%20Backpropagation.csv', sep=',')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1      Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0        NaN         No  Nama Mahasiswa        IPK  Jumlah SKS
# 1        NaN          1           Naila        3.7         120
# 2        NaN          2            Andi        3.0          90
# 3        NaN          3            Budi        4.0         150
# 4        NaN          4            Abel        2.6          75
#
#           Unnamed: 5
# 0  Lulus Tepat Waktu
# 1                 Ya
# 2              Tidak
# 3                 Ya
# 4              Tidak

# %% [markdown]
# link excel dibawah ini:
#
# [Manual Backpropagation](https://docs.google.com/spreadsheets/d/1JiU5Bts6xrDcqDF6opTEvd4-dkpIhdBUzwV_XvtzEis/edit?usp=sharing)
